# %%
"""
Basic similarity search example. Used in the original txtai demo.
Requires streamlit to be installed.
  pip install streamlit
"""

import os

import streamlit as st

from txtai.embeddings import Embeddings


class Application:
    """
    Main application.
    """

    def __init__(self):
        """
        Creates a new application.
        """

        # Create embeddings model, backed by sentence-transformers & transformers
        self.embeddings = Embeddings({"path": "sentence-transformers/nli-mpnet-base-v2"})

    def run(self):
        """
        Runs a Streamlit application.
        """

        st.title("Similarity Search")
        st.markdown("This application runs a basic similarity search that identifies the best matching row for a query.")

        data = [
            "US tops 5 million confirmed virus cases",
            "Canada's last fully intact ice shelf has suddenly collapsed, forming a Manhattan-sized iceberg",
            "Beijing mobilises invasion craft along coast as Taiwan tensions escalate",
            "The National Park Service warns against sacrificing slower friends in a bear attack",
            "Maine man wins $1M from $25 lottery ticket",
            "Make huge profits without work, earn up to $100,000 a day",
        ]

        data = st.text_area("Data", value="\n".join(data))
        query = st.text_input("Query")

        data = data.split("\n")

        if query:
            # Get index of best section that best matches query
            uid = self.embeddings.similarity(query, data)[0][0]
            st.write(data[uid])


@st.cache(allow_output_mutation=True)
def create():
    """
    Creates and caches a Streamlit application.
    Returns:
        Application
    """

    return Application()


if __name__ == "__main__":
    os.environ["TOKENIZERS_PARALLELISM"] = "false"

    # Create and run application
    app = create()
    app.run()
# Out:
# 2022-08-16 15:47:56.426 INFO    numexpr.utils: NumExpr defaulting to 4 threads.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 11>()
#       7 import os
#       9 import streamlit as st
# ---> 11 from txtai.embeddings import Embeddings
#      14 class Application:
#      15     """
#      16     Main application.
#      17     """
#
# ModuleNotFoundError: No module named 'txtai'

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.12.0-py2.py3-none-any.whl (9.1 MB)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-9.0.0-cp39-cp39-win_amd64.whl (19.6 MB)
# Collecting altair>=3.2.0
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: click>=7.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: toml in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting blinker>=1.0.0
#   Using cached blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: python-dateutil in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (3.19.1)
# Requirement already satisfied: packaging>=14.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: requests>=2.4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (2.27.1)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: numpy in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (1.4.2)
# Collecting validators>=0.2
#   Using cached validators-0.20.0-py3-none-any.whl
# Requirement already satisfied: rich>=10.11.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (12.5.1)
# Requirement already satisfied: watchdog in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: entrypoints in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: colorama in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.5)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (6.9.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (8.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.12)
# Requirement already satisfied: pickleshare in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: decorator in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: backcall in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.11.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (302)
# Requirement already satisfied: fastjsonschema in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.15.1)
# Requirement already satisfied: wcwidth in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.9)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)
# Requirement already satisfied: defusedxml in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: testpath in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: bleach in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: executing in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.0.5)
# Installing collected packages: smmap, gitdb, validators, semver, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
# Successfully installed altair-4.2.0 blinker-1.5 gitdb-4.0.9 gitpython-3.1.27 pyarrow-9.0.0 pydeck-0.7.1 pympler-1.0.1 semver-2.13.0 smmap-5.0.0 streamlit-1.12.0 validators-0.20.0
