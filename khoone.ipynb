# %%
# !pip install jdatetime
import pandas as pd
import jdatetime 
df1 = pd.read_csv('maskan.csv')
print(df1.head())
# Out:
# ...
#    price       jdate
# 0  43709  1396/01/30
# 1  45336  1396/02/31
# 2  45631  1396/03/31
# 3  46197  1396/04/31
# 4  46663  1396/05/31

# %%
import matplotlib.pyplot as plt
plt.plot(df1.jdate, df1.price)
#plt.ticklabel_format(style='plain')
plt.ticklabel_format(style='plain', axis='y')
plt.show()
