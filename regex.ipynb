# %%
import re
s = 'اتان استخراج شده از معدن(1110412308)'
s.replace(s[s.find("("):s.find(")")+1], '')
# Out:
# 'اتان استخراج شده از معدن'

# %%
with open('isic_full2_.txt', "a", encoding="UTF-8") as w:
    with open('isic_full1.txt', encoding="UTF-8") as f:
        corpus = f.read().splitlines()
    for s in corpus:
#    s = 'اتان استخراج شده از معدن(1110412308)'
        print(s.replace(s[s.find("("):s.find(")")+1], ''))
        w.write(s.replace(s[s.find("("):s.find(")")+1], ''))
        #w.write("\n\l")
# Out:
# كشاورزي، شكار و فعاليتهاي خدماتي وابسته
# جنگلداري، قطع اشجار و فعاليتهاي خدماتي وابسته
# ماهيگيري، اداره هچري ها و مزرعه هاي تكثير و پرورش ماهي؛ فعاليتهاي خدماتي در راستاي ماهيگيري
# استخراج نفت خام و گاز طبيعي؛ فعاليتهاي خدماتي جنبي استخراج نفت و گاز، به استثناي بررسي هاي اكتشافي
# استخراج نفت خام و گاز طبيعي
# محصولات حاصل از استخراج چاه نفت و يا معادن داراي مواد قيري به جز هيدروكربنهاي گازي خام
# نفت خام
# نفت خام استخراج شده از چاه
# نفت خام توليد شده از سنگ و ماسه قيردار
# هيدروكربنهاي گازي خام
# متان استخراج شده از معدن
# اتان استخراج شده از معدن
# بوتان استخراج شده از معدن
# پروپان استخراج شده از معدن
# گاز طبيعي خام
# گاز طبيعي خام مايع شده
# گاز طبيعي خام به حالت گاز
# ساخت محصولات غذايي و انواع آشاميدني ها
# توليد، عمل آوري و حفاظت گوشت و محصولات گوشتي از فساد
# عمل آوري و بسته بندي گوشت انواع دام
# توليد، عمل آوري و بسته بندي گوشت گاو
# گوشت گاو تازه و بسته بندي شده، به صورت لاشه
# گوشت گاو تازه و بسته بندي شده، به صورت قطعه قطعه شده
# ...

# %%
re.findall(r'\([^)]*\),', s)
# Out:
# []

# %%
s[s.find("("):s.find(")")+1]
# Out:
# '(1110412308)'
