# %%
# !pip install dadmatools
# Out:
# Requirement already satisfied: dadmatools in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: conllu in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (4.5.2)
# Requirement already satisfied: bpemb>=0.3.3 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.3.3)
# Requirement already satisfied: segtok>=1.5.7 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.5.11)
# Requirement already satisfied: py7zr>=0.17.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.20.0)
# Requirement already satisfied: h5py>=3.3.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (3.6.0)
# Requirement already satisfied: nltk in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (3.3)
# Requirement already satisfied: tabulate>=0.8.6 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.8.9)
# Requirement already satisfied: supar==1.1.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.1.2)
# Requirement already satisfied: folium>=0.2.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.12.1.post1)
# Requirement already satisfied: spacy>=3.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (3.4.0)
# Requirement already satisfied: Deprecated==1.2.6 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.2.6)
# Requirement already satisfied: NERDA in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.0.0)
# Requirement already satisfied: hyperopt>=0.2.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.2.7)
# Requirement already satisfied: gensim>=3.6.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (4.1.2)
# Requirement already satisfied: gdown>=4.3.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (4.5.1)
# Requirement already satisfied: transformers==4.9.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (4.9.1)
# Requirement already satisfied: pytorch-transformers>=1.1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.2.0)
# Requirement already satisfied: pyconll>=3.1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (3.1.0)
# Requirement already satisfied: html2text in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (2020.1.16)
# Requirement already satisfied: torch>=1.7.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (1.12.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (2.8.0.dev2021122109)
# Requirement already satisfied: sklearn>=0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from dadmatools) (0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from Deprecated==1.2.6->dadmatools) (1.12.1)
# Requirement already satisfied: stanza in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from supar==1.1.2->dadmatools) (1.4.0)
# Requirement already satisfied: dill in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from supar==1.1.2->dadmatools) (0.3.5.1)
# Requirement already satisfied: filelock in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (3.6.0)
# Requirement already satisfied: sacremoses in c:\users\ebrahimpour.m\appdata\roaming\python\python39\site-packages (from transformers==4.9.1->dadmatools) (0.0.53)
# Requirement already satisfied: numpy>=1.17 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (1.21.5)
# Requirement already satisfied: packaging in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (5.4.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (2022.3.15)
# Requirement already satisfied: requests in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (2.27.1)
# Requirement already satisfied: huggingface-hub==0.0.12 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (0.0.12)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from transformers==4.9.1->dadmatools) (4.64.0)
# Requirement already satisfied: typing-extensions in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from huggingface-hub==0.0.12->transformers==4.9.1->dadmatools) (4.1.1)
# Requirement already satisfied: sentencepiece in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from bpemb>=0.3.3->dadmatools) (0.1.96)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from folium>=0.2.1->dadmatools) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from folium>=0.2.1->dadmatools) (0.5.0)
# Requirement already satisfied: six in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from gdown>=4.3.1->dadmatools) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from gdown>=4.3.1->dadmatools) (4.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from gensim>=3.6.0->dadmatools) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from gensim>=3.6.0->dadmatools) (1.7.3)
# Requirement already satisfied: py4j in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from hyperopt>=0.2.5->dadmatools) (0.10.9.7)
# Requirement already satisfied: cloudpickle in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from hyperopt>=0.2.5->dadmatools) (2.0.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from hyperopt>=0.2.5->dadmatools) (2.7.1)
# Requirement already satisfied: future in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from hyperopt>=0.2.5->dadmatools) (0.18.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from jinja2>=2.9->folium>=0.2.1->dadmatools) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from packaging->transformers==4.9.1->dadmatools) (3.0.4)
# Requirement already satisfied: brotli>=1.0.9 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (1.0.9)
# Requirement already satisfied: pyppmd<0.19.0,>=0.18.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (0.18.3)
# Requirement already satisfied: inflate64>=0.3.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (0.3.0)
# Requirement already satisfied: texttable in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (1.6.4)
# Requirement already satisfied: pyzstd>=0.14.4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (0.15.3)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (0.2.3)
# Requirement already satisfied: pybcj>=0.6.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (1.0.1)
# Requirement already satisfied: psutil in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (5.8.0)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from py7zr>=0.17.2->dadmatools) (3.15.0)
# Requirement already satisfied: boto3 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pytorch-transformers>=1.1.0->dadmatools) (1.21.32)
# Requirement already satisfied: scikit-learn in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from sklearn>=0.0->dadmatools) (1.0.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (3.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (0.6.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (1.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (1.9.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (1.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (2.4.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (0.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (8.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from spacy>=3.0.0->dadmatools) (61.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests->transformers==4.9.1->dadmatools) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests->transformers==4.9.1->dadmatools) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests->transformers==4.9.1->dadmatools) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests->transformers==4.9.1->dadmatools) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->dadmatools) (0.7.8)
# Requirement already satisfied: colorama in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.9.1->dadmatools) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0.0->dadmatools) (8.0.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=4.3.1->dadmatools) (2.3.1)
# Requirement already satisfied: botocore<1.25.0,>=1.24.32 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from boto3->pytorch-transformers>=1.1.0->dadmatools) (1.24.32)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from boto3->pytorch-transformers>=1.1.0->dadmatools) (0.5.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from boto3->pytorch-transformers>=1.1.0->dadmatools) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from botocore<1.25.0,>=1.24.32->boto3->pytorch-transformers>=1.1.0->dadmatools) (2.8.2)
# Requirement already satisfied: progressbar in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from NERDA->dadmatools) (2.5)
# Requirement already satisfied: pandas in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from NERDA->dadmatools) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from pandas->NERDA->dadmatools) (2021.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from requests->transformers==4.9.1->dadmatools) (1.7.1)
# Requirement already satisfied: joblib in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from sacremoses->transformers==4.9.1->dadmatools) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from scikit-learn->sklearn>=0.0->dadmatools) (2.2.0)
# Requirement already satisfied: emoji in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from stanza->supar==1.1.2->dadmatools) (2.0.0)
# Requirement already satisfied: protobuf in c:\users\ebrahimpour.m\anaconda3\lib\site-packages (from stanza->supar==1.1.2->dadmatools) (3.19.1)

# %%
from dadmatools.models.normalizer import Normalizer

normalizer = Normalizer(
    full_cleaning=False,
    unify_chars=True,
    refine_punc_spacing=True,
    remove_extra_space=True,
    remove_puncs=False,
    remove_html=False,
    remove_stop_word=False,
    replace_email_with="<EMAIL>",
    replace_number_with=None,
    replace_url_with="",
    replace_mobile_number_with=None,
    replace_emoji_with=None,
    replace_home_number_with=None
)

text = """
<p>
دادماتولز اولین نسخش سال ۱۴۰۰ منتشر شده. 
امیدواریم که این تولز بتونه کار با متن رو براتون شیرین‌تر و راحت‌تر کنه
لطفا با ایمیل dadmatools@dadmatech.ir با ما در ارتباط باشید
آدرس گیت‌هاب هم که خب معرف حضور مبارک هست:
 https://github.com/Dadmatech/DadmaTools
</p>
"""
normalized_text = normalizer.normalize(text)
#<p> دادماتولز اولین نسخش سال 1400 منتشر شده. امیدواریم که این تولز بتونه کار با متن رو براتون شیرین‌تر و راحت‌تر کنه لطفا با ایمیل <EMAIL> با ما در ارتباط باشید آدرس گیت‌هاب هم که خب معرف حضور مبارک هست: </p>

#full cleaning
normalizer = Normalizer(full_cleaning=True)
normalized_text = normalizer.normalize(text)
#دادماتولز نسخش سال منتشر تولز بتونه کار متن براتون شیرین‌تر راحت‌تر کنه ایمیل ارتباط آدرس گیت‌هاب معرف حضور مبارک
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 from dadmatools.models.normalizer import Normalizer
# ----> 3 normalizer = Normalizer(
#       4     full_cleaning=False,
#       5     unify_chars=True,
#       6     refine_punc_spacing=True,
#       7     remove_extra_space=True,
#       8     remove_puncs=False,
#       9     remove_html=False,
#      10     remove_stop_word=False,
#      11     replace_email_with="<EMAIL>",
#      12     replace_number_with=None,
#      13     replace_url_with="",
#      14     replace_mobile_number_with=None,
#      15     replace_emoji_with=None,
#      16     replace_home_number_with=None
#      17 )
#      19 text = """
#      20 <p>
#      21 دادماتولز اولین نسخش سال ۱۴۰۰ منتشر شده.
#    (...)
#      26 </p>
#      27 """
#      28 normalized_text = normalizer.normalize(text)
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\normalizer.py:33, in Normalizer.__init__(self, full_cleaning, unify_chars, refine_punc_spacing, remove_extra_space, remove_puncs, remove_html, remove_stop_word, replace_email_with, replace_number_with, replace_url_with, replace_mobile_number_with, replace_emoji_with, replace_home_number_with)
#      31 self.remove_puncs = remove_puncs
#      32 self.remove_stop_word = remove_stop_word
# ---> 33 self.STOPWORDS = open(prefix+save_dir+'stopwords-fa.py').read().splitlines()
#      34 self.PUNCS = string.punctuation.replace('<', '').replace('>', '') + '،؟'
#      35 if full_cleaning:
#
# File ~\Anaconda3\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 220: character maps to <undefined>

# %%
import dadmatools.pipeline.language as language

# here lemmatizer and pos tagger will be loaded
# as tokenizer is the default tool, it will be loaded as well even without calling
pips = 'tok,lem,pos,dep,chunk,cons,spellchecker,kasreh' 
nlp = language.Pipeline(pips)

# you can see the pipeline with this code
print(nlp.analyze_pipes(pretty=True))

# doc is an SpaCy object
doc = nlp('از قصهٔ کودکیشان که می‌گفت، گاهی حرص می‌خورد!')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import dadmatools.pipeline.language as language
#       3 # here lemmatizer and pos tagger will be loaded
#       4 # as tokenizer is the default tool, it will be loaded as well even without calling
#       5 pips = 'tok,lem,pos,dep,chunk,cons,spellchecker,kasreh'
#
# File ~\Anaconda3\lib\site-packages\dadmatools\pipeline\language.py:12, in <module>
#      10 import dadmatools.models.mw_tokenizer as mwt
#      11 import dadmatools.models.lemmatizer as lemmatizer
# ---> 12 import dadmatools.models.postagger as tagger
#      13 import dadmatools.models.dependancy_parser as dp
#      14 import dadmatools.models.constituency_parser as conspars
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\postagger.py:1, in <module>
# ----> 1 from dadmatools.models.flair import embeddings as Embeddings
#       2 import copy
#       3 from dadmatools.models.flair.data import Dictionary
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\flair\__init__.py:15, in <module>
#      12     device = torch.device("cpu")
#      14 from . import data
# ---> 15 from dadmatools.models.flair import models
#      16 from . import visual
#      17 from . import trainers
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\flair\models\__init__.py:1, in <module>
# ----> 1 from .sequence_tagger_model import SequenceTagger, FastSequenceTagger
#       2 from .dependency_model import SemanticDependencyParser
#       3 from .language_model import LanguageModel
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\flair\models\sequence_tagger_model.py:16, in <module>
#      14 from dadmatools.models.flair.data import Dictionary, Sentence, Token, Label
#      15 from dadmatools.models.flair.datasets import DataLoader
# ---> 16 from dadmatools.models.flair.embeddings import TokenEmbeddings
#      17 from dadmatools.models.flair.file_utils import cached_path
#      19 from typing import List, Tuple, Union
#
# File ~\Anaconda3\lib\site-packages\dadmatools\models\flair\embeddings.py:32, in <module>
#      16 import pdb
#      17 from pytorch_transformers import (
#      18     RobertaTokenizer,
#      19     RobertaModel,
#    (...)
#      29     PreTrainedModel,
#      30 )
# ---> 32 from transformers import XLNetTokenizer, T5Tokenizer, GPT2Tokenizer, AutoTokenizer, AutoConfig, AutoModel
#      34 from transformers import (
#      35     XLNetModel,
#      36     XLNetTokenizer,
#    (...)
#      40     XLMRobertaTokenizer,
#      41     )
#      43 ####### just for removing the warning log of transformer
#
# File ~\Anaconda3\lib\site-packages\transformers\file_utils.py:1978, in _LazyModule.__getattr__(self, name)
#    1976 elif name in self._class_to_module.keys():
#    1977     module = self._get_module(self._class_to_module[name])
# -> 1978     value = getattr(module, name)
#    1979 else:
#    1980     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~\Anaconda3\lib\site-packages\transformers\file_utils.py:1977, in _LazyModule.__getattr__(self, name)
#    1975     value = self._get_module(name)
#    1976 elif name in self._class_to_module.keys():
# -> 1977     module = self._get_module(self._class_to_module[name])
#    1978     value = getattr(module, name)
#    1979 else:
#
# File ~\Anaconda3\lib\site-packages\transformers\file_utils.py:1986, in _LazyModule._get_module(self, module_name)
#    1985 def _get_module(self, module_name: str):
# -> 1986     return importlib.import_module("." + module_name, self.__name__)
#
# File ~\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\Anaconda3\lib\site-packages\transformers\models\auto\modeling_auto.py:230, in <module>
#     228 from ..pegasus.modeling_pegasus import PegasusForCausalLM, PegasusForConditionalGeneration, PegasusModel
#     229 from ..prophetnet.modeling_prophetnet import ProphetNetForCausalLM, ProphetNetForConditionalGeneration, ProphetNetModel
# --> 230 from ..rag.modeling_rag import (  # noqa: F401 - need to import all RagModels to be in globals() function
#     231     RagModel,
#     232     RagSequenceForGeneration,
#     233     RagTokenForGeneration,
#     234 )
#     235 from ..reformer.modeling_reformer import (
#     236     ReformerForMaskedLM,
#     237     ReformerForQuestionAnswering,
#    (...)
#     240     ReformerModelWithLMHead,
#     241 )
#     242 from ..retribert.modeling_retribert import RetriBertModel
#
# File ~\Anaconda3\lib\site-packages\transformers\models\rag\modeling_rag.py:30, in <module>
#      28 from ...utils import logging
#      29 from .configuration_rag import RagConfig
# ---> 30 from .retrieval_rag import RagRetriever
#      33 logger = logging.get_logger(__name__)
#      35 _CONFIG_FOR_DOC = "RagConfig"
#
# File ~\Anaconda3\lib\site-packages\transformers\models\rag\retrieval_rag.py:36, in <module>
#      33     from datasets import Dataset, load_dataset, load_from_disk
#      35 if is_faiss_available():
# ---> 36     import faiss
#      39 logger = logging.get_logger(__name__)
#      42 LEGACY_INDEX_PATH = "https://storage.googleapis.com/huggingface-nlp/datasets/wiki_dpr/"
#
# File ~\Anaconda3\lib\site-packages\faiss\__init__.py:51, in <module>
#      48 import warnings
#      50 # We import * so that the symbol foo can be accessed as faiss.foo.
# ---> 51 from .loader import *
#      54 __version__ = "%d.%d.%d" % (FAISS_VERSION_MAJOR,
#      55                             FAISS_VERSION_MINOR,
#      56                             FAISS_VERSION_PATCH)
#      58 ##################################################################
#      59 # The functions below add or replace some methods for classes
#      60 # this is to be able to pass in numpy arrays directly
#      61 # The C++ version of the classnames will be suffixed with _c
#      62 ##################################################################
#
# File ~\Anaconda3\lib\site-packages\faiss\loader.py:65, in <module>
#      62 if not has_AVX2:
#      63     # we import * so that the symbol X can be accessed as faiss.X
#      64     logger.info("Loading faiss.")
# ---> 65     from .swigfaiss import *
#      66     logger.info("Successfully loaded faiss.")
#
# File ~\Anaconda3\lib\site-packages\faiss\swigfaiss.py:13, in <module>
#      11 # Import the low-level C/C++ module
#      12 if __package__ or "." in __name__:
# ---> 13     from . import _swigfaiss
#      14 else:
#      15     import _swigfaiss
#
# ImportError: DLL load failed while importing _swigfaiss: The specified module could not be found.
