# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
with open('restult_output_new.txt', encoding="UTF-8") as f:
    sentences = f.read().splitlines()
print(sentences)
# Out:
# ['\ufeffاخذ تسهیلات و اعتبارات از کلیه بانکها و موسسات مالی و اعتباری دولتی و خصوصی داخلی یا خارجی برای شرکت', 'عقد قرارداد با سازمانها ،  نهادها ، شرکتها و موسسات دولتی و غیردولتی ادارات در زمینه موضوع شرکت و شرکت در نمایشگاههای داخلی و خارجی', 'انجام فعالیتهای مجاز ،  تجاری و بازرگانی و اقتصادی', 'بازاریابی الکترونیکی', 'تجارت الکترونیکی غیرهرمی و غیرشبکه\u200cای با استفاده از نرم¬افزار و از¬طریق فضای مجازی', 'فعالیت خدمات و کالا در فضای مجازی به صورت مستقیم یا با واسطه', 'ارائه خدمات و کالا در فضای مجازی به صورت مستقیم یا با واسطه', 'خرید اینترنتی انواع کالا و خدمات مجاز از¬طریق ایجاد و راه\u200cاندازی وب¬سایت', 'فروش اینترنتی انواع کالا و خدمات مجاز از¬طریق ایجاد و راه\u200cاندازی وب¬سایت', 'برقراری ارتباط بین مشتری و فروشنده', 'برقراری ارتباط با سامانه تجاری اینترنتی و فروشگاه\u200cهای مجازی جهت بازاریابی محصولات ،  کالاها و خدمات مجاز', 'مشاهده فنی در زمینه فعالیتها و خدمات رایانه\u200cای طراحی وب میزبانی ،شبکه\u200cهای رایانه\u200cای', 'طراحی فنی در زمینه فعالیتها و خدمات رایا
# ...

# %%
with open('ubject.txt', encoding="UTF-8") as f:
    lines = f.read().splitlines()
print(lines)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
sentence_embeddings = model.encode(lines)

# %%
for sentence, embedding in zip(lines, sentence_embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")

# %%
topic_model = BERTopic(language="persian", verbose=True)
topics, _ = topic_model.fit_transform(sentences)

# %%
topic_model.update_topics(sentences, topics, n_gram_range=(1, 3))

# %%
topic_model.get_topic_info().head(5)

# %%
topic_model.get_topic(topic_model.get_topic_freq().iloc[1].Topic)

# %%
topics_per_class = topic_model.topics_per_class(sentences, topics, classes=classes)
fig_unsupervised = topic_model.visualize_topics_per_class(topics_per_class, top_n=10)
fig_unsupervised

# %%
from sentence_transformers import SentenceTransformer, util

paraphrases = util.paraphrase_mining(model, sentences)

for paraphrase in paraphrases[0:10]:
    score, i, j = paraphrase
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences[i], sentences[j], score))

# %%
from bertopic import BERTopic
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
topics, probs = topic_model.fit_transform(lines)

# %%
topic_model.get_topic_info()

# %%
print(sentences)

# %%
topic_model.get_topic(0)

# %%
topic = BERTopic(language="persian")

# %%
topics, probs = topic.fit_transform(lines)

# %%
topic_model1 = BERTopic(verbose=True)
topics, _ = topic_model1.fit_transform(sentences)

# %%
topic_model.visualize_topics()

# %%
topic_model1.visualize_topics()

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import TfidfVectorizer

# Create TF-IDF sparse matrix
vectorizer = TfidfVectorizer(min_df=5)
embeddings = vectorizer.fit_transform(sentences)

# Model
model = BERTopic(language="persian")
topics, probabilities = model.fit_transform(sentences, embeddings)

# %%
model.get_topic_info()

# %%
topic_model.get_topic(1)
# Out:
# [('کشاورزی', 0.03672141137955935),
#  ('پرورش', 0.019770008135267886),
#  ('گلخانه', 0.01726224390928197),
#  ('کشت', 0.014111546397942957),
#  ('محصولات کشاورزی', 0.013851886011348999),
#  ('محصولات', 0.013730595919964264),
#  ('گیاهان', 0.01364757873272454),
#  ('کاشت', 0.012659893794633026),
#  ('طیور', 0.01253747195861739),
#  ('های کشاورزی', 0.011397701780561263)]
