# %%
"""
This is a more complex example on performing clustering on large scale dataset.
This examples find in a large set of sentences local communities, i.e., groups of sentences that are highly
similar. You can freely configure the threshold what is considered as similar. A high threshold will
only find extremely similar sentences, a lower threshold will find more sentence that are less similar.
A second parameter is 'min_community_size': Only communities with at least a certain number of sentences will be returned.
The method for finding the communities is extremely fast, for clustering 50k sentences it requires only 5 seconds (plus embedding comuptation).
In this example, we download a large set of questions from Quora and then find similar questions in this set.
"""
from sentence_transformers import SentenceTransformer, util
import os
import csv
import time


# Model for computing sentence embeddings. We use one trained for similar questions detection
model = SentenceTransformer('all-MiniLM-L6-v2')

# We donwload the Quora Duplicate Questions Dataset (https://www.quora.com/q/quoradata/First-Quora-Dataset-Release-Question-Pairs)
# and find similar question in it
#url = "http://qim.fs.quoracdn.net/quora_duplicate_questions.tsv"
#dataset_path = "quora_duplicate_questions.tsv"
#max_corpus_size = 50000  # We limit our corpus to only the first 50k questions


# Check if the dataset exists. If not, download and extract
# Download dataset if needed
#if not os.path.exists(dataset_path):
#    print("Download dataset")
#    util.http_get(url, dataset_path)

# Get all unique sentences from the file
#corpus_sentences = set()
#with open(dataset_path, encoding='utf8') as fIn:
#    reader = csv.DictReader(fIn, delimiter='\t', quoting=csv.QUOTE_MINIMAL)
#    for row in reader:
#        corpus_sentences.add(row['question1'])
#        corpus_sentences.add(row['question2'])
#        if len(corpus_sentences) >= max_corpus_size:
#            break

#corpus_sentences = list(corpus_sentences)
with open('restult_output_new.txt', encoding="UTF-8") as f:
    corpus_sentences = f.read().splitlines()
print("Encode the corpus. This might take a while")

corpus_embeddings = model.encode(corpus_sentences, batch_size=64, show_progress_bar=True, convert_to_tensor=True)


print("Start clustering")
start_time = time.time()

#Two parameters to tune:
#min_cluster_size: Only consider cluster that have at least 25 elements
#threshold: Consider sentence pairs with a cosine-similarity larger than threshold as similar
clusters = util.community_detection(corpus_embeddings, min_community_size=25, threshold=0.75)

print("Clustering done after {:.2f} sec".format(time.time() - start_time))

#Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    for sentence_id in cluster[0:3]:
        print("\t", corpus_sentences[sentence_id])
    print("\t", "...")
    for sentence_id in cluster[-3:]:
        print("\t", corpus_sentences[sentence_id])
# Out:
# Encode the corpus. This might take a while
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]
# Start clustering
# Clustering done after 78.17 sec
#
# Cluster 1, #3427 Elements
# 	 ﻿اخذ تسهیلات و اعتبارات از کلیه بانکها و موسسات مالی و اعتباری دولتی و خصوصی داخلی یا خارجی برای شرکت
# 	 عقد قرارداد با سازمانها ،  نهادها ، شرکتها و موسسات دولتی و غیردولتی ادارات در زمینه موضوع شرکت و شرکت در نمایشگاههای داخلی و خارجی
# 	 انجام فعالیتهای مجاز ،  تجاری و بازرگانی و اقتصادی
# 	 ...
# 	 مشاوره و مطالعات مهندسی مخازن
# 	 مشاوره و مطالعات زمین شناسی
# 	 تکمیل و بهره برداری مطالعات اقتصادی در داخل و خارج از کشور
#
# Cluster 2, #315 Elements
# 	 تولید نرم¬افزارهای مجاز
# 	 راه‌اندازی پشتیبانی کلیه تجهیزات و سخت افزارهای مرتبط با تجارت الکترونیک
# 	 فن آوری اطلاعات
# 	 ...
# 	 صنایع نساجی و ریسندگی
# 	 نظارت پروژه های توسعه
# 	 مشاوره و مطالعات مهندسی حفاری
#
# Cluster 3, #242 Elements
#
#
#
# 	 ...
#
#
#
#
# Cluster 4, #78 Elements
# 	 گود برداری
# 	 سدسازی
# 	 محوطه سازی
# 	 ...
# 	 بازرگانی
# 	 جاجیم بافی
# 	 جاجیم بافی
#
# Cluster 5, #71 Elements
# 	 صادرات کلیه کالاهای مجاز بازرگانی
# 	 صادرات کلیه کالاهای بازرگانی
# 	 صادرات کلیه کالاهای بازرگانی
# 	 ...
# 	 صادرات و واردات کالاهای مجاز بازرگانی
# 	 صادرات و واردات کالاهای مجاز بازرگانی
# 	 مشاوره و مطالعات پتروفیزیک
#
# Cluster 6, #46 Elements
# 	 نصب انواع کفپوش، جدول، دال و سنگ
# 	 آشپزخانه و رستوران
# 	 بهره برداری
# 	 ...
# 	 پل سازی
# 	 رنگ آمیزی جداول
# 	 مخازن بتنی
#
# Cluster 7, #44 Elements
# 	 زهکشی کشاورزی و باغبانی
# 	 طرح¬های تکنولوژیکی در زمینه موضوع شرکت
# 	 عملیات به زراعی
# 	 ...
# 	 تولید
# 	 تولید
# 	 سوراخ کردن گوش
#
# Cluster 8, #38 Elements
# 	 صادرات کلیه کالاهای مجاز
# 	 صادرات مواد بهداشتی
# 	 ساخت راه آهن، مترو، باند و فرودگاه، برج مراقبت
# 	 ...
# 	 احداث سازه و سوله
# 	 اقلام پیش ساخته
# 	 صنایع فیلم و بسته بندی
#
# Cluster 9, #37 Elements
# 	 احیا اراضی موات
# 	 مدیریت منابع
# 	 مشاوره مدیریت استراتژیک
# 	 ...
# 	 ماسه پاشی (سندبلاست)
# 	 جدول کشی
# 	 مشاوره و مطالعات ژئوفیزیک
#
# Cluster 10, #36 Elements
# 	 راهسازی
# 	 اداره رستوران و بوفه
# 	 اداره رستوران و بوفه
# 	 ...
# 	 راهداری
# 	 ساخت پیاده رو
# 	 مدیریت ریسک
#
# Cluster 11, #34 Elements
# 	 طراحی، مشاوره، محاسبه، نظارت فنی و اجرای کلیه پروژه های عمرانی اعم از فلزی و بتنی، ابنیه سبک و سنگین، ساخت راه و باند، راه آهن، مترو، باند و فرودگاه، برج مراقبت، آماده سازی و اکتشاف و استخراج معادن، نقشه برداری، تسطیح اراضی، گود برداری، محوطه سازی، احداث و نگهداری فنی پارکها و فضای سبز، تاسیسات برقی و مکانیکی ساختمانها و کارخانجات صنعتی و نیروگاه ها
# 	 مطالعه و پزوهش، مشاوره، طراحی، نظارت، ساخت، متره و برآورد، مرمت و بازسازی، پیمانکاری و بهره برداری، نگهداری و سرمایه گذاری در املاک و مستغلات در زمینه کلیه امور عمرانی و اجرایی از جمله انواع شهرک ها، مجتمع های مسکونی، تجاری، اداری، صنعتی و نظامی، آموزشی، ورزشی، بهداشتی و درمانی.طراحی
# 	 شرکت در کلیه مناقصات و مزایدات دولتی و خصوصی در رشته ورزشی فوتبال و فوتسال صرفا جهت حضور در مسابقات داخلی شهرستان طبق مجوز کسب شده از اداره ورزش و جوانان شهرستان کاشان و همچنین جهت شرکت در مسابقات استانی در سطح کشوری با کسب مجوز های مربوطه از مراجع ذی الصلاح  توسعه زیر ساخت های لازم برای ساخت و نصب و راه اندازی و بهره برداری از نیروگاه های انرژی های تجدید پذیر و خورشیدی شامل کلیه اقدامات مربوط به اخذ گواهی و مجوزهای لازم از مراجع ذیصلاح – انجام مطالعات مقدماتی و امکان سنجی فنی و مالی و اقتصادی – فعالیت در زمینه واردات و صادرات و خرید و فروش کلیه کالاها و خدمات مجاز مربوط به آن از منابع داخلی و خارجی – فعالیت در زمینه واردات و صادرات و خرید و فروش پنل های خورشیدی و تجهیزات وابسته و خرید وفروش مربوط به حوزه فعالیت از قبیل پنل های خورشیدی و کابل و اینورتر و تجهیزات مربوط به نیروگاه خورشیدی و خدمات مجاز مربوط به آن از منابع داخلی و خارجی – برگزاری نمایشگاه ها برای هرنوع کالای بازرگانی بجز فرهنگی – شرکت در مناقصات و مزایدات و عقد قرارداد با اشخاص حقیقی و حقوقی و ارگان ها و ادارات و کارخانجات و موسسات دولتی و خصوصی – اخذ تسهیلات مالی و اعتباری از بانک ها و موسسات مالی و اعتباری صرفاً جهت تحقق اهداف شرکت
# 	 ...
# 	 خرید، فروش، توزیع، تولید، بسته بندی، واردات و صادرات و ترخیص و خدمات پس از فروش کلیه کالاهای بازرگانی مجاز ومکمل های غذایی دامی وانسانی، رژیمی و ورزشی ومواد غذایی مجاز و مواد لبنیاتی، برنج، چای، عسل، زیتون، ترشیجات، خشکبار، محصولات سلولزی، روغن، محصولات کنسروی ونهاد های دام و طیور، دام و طیور زنده، چرم و محصولات چرمی، گیاهان دارویی، لوازم ارایشی و بهداشتی، لوازم و ماشین آلات صنعتی و کشاورزی و دامپروی و دامپزشکی، انواع حبوبات و غلات، مواد پروتئینی مجاز، نوشیدی های مجاز
# 	 صادرات و واردات کلیه کالاهای مجاز بازرگانی از جمله انواع لوازم خانگی، گوشی های موبایل، لوازم صوتی و تصویری و قطعات یدکی مربوطه، کالاهای الکتریکی، الکترونیکی، ورزشی و تجهیزات پزشکی، کامپیوتر و قطعات کامپیوتر و تجهیزات شبکه های کامپیوتری، تجهیزات گرمایش و سرمایش
# 	 انجام کلیه امورپیمانکاری مربوط به ساخت راهها نظیرراههای اصلی وفرعی وبزرگراهها راههای ریلی باند فرودگاه سیستم های انتقال هوایی پایدار تونل ها پل ها راههای زیرزمینی پیمانکاری صنعت و معدن به غیراز نفت و گاز و پتروشیمی، کشاورزی
#
# Cluster 12, #31 Elements
# 	 حفاظت کاتودی
# 	 فضای سبز
# 	 لوله کشی آب وفاضلاب،برق،آب
# 	 ...
# 	 فضای سبز
# 	 نقشه کشی
# 	 حفاظت کاتودی
#
# Cluster 13, #30 Elements
# 	 مدیریت دانش
# 	 پوشش (لاینیگ) و ایستگاه های پمپاژ آب و فاضلاب کوچک و نظایر آن
# 	 نصب، راه اندازی سرویس و نگهداری آنتن مرکزی، آسانسور، پله برقی، درب های برقی، فنی الکترونیک، شبکه های کامپیوتری
# 	 ...
# 	 تولید کیف و کفش
# 	 مدیریت دانش
# 	 نظارت پروژه های اکتشاف
#
# Cluster 14, #30 Elements
# 	 هتل داری
# 	 صادرات مواد شیمیایی
# 	 اخذ انواع ضمانتنامه بانکی
# 	 ...
# 	 گاردریل بندی
# 	 بسته بندی
# 	 بسته بندی
#
# Cluster 15, #30 Elements
# 	 امور مربوط به محیط زیست و فعالیت های زیست محیطی
# 	 مدیریت تغییر
# 	 تولید پروفیل های PV
# 	 ...
# 	 تزریقات
# 	 مدیریت تغییر
# 	 فرآوری
#
# Cluster 16, #30 Elements
# 	 قبول مسوولیت و همکاری با وزارتخانه ها، سازمانها و نهادهای رسمی در انجام وظایف و تکالیفی که این دستگاه ها به انجمن های صنفی محول می کنند و آمادگی برای ارائه مشورتهای لازم به آنها
# 	 بهره برداری از وسایل کشاورزی، آبیاری و مستحدثات، اعیانی، مزارع، باغات، کارخانجات، سهام کارخانجات و سایر امکانات دولتی قابل واگذاری برابر قانون سیاست های اصل ۴۴ قانون اساسی در حوزه عمل شرکت
# 	 انجام کلیه فعالیتهای و ارائه خدمات در زمینه اعتلا و تعمیم آموزش و پرورش کشور با تصویب و تایید وزارت آموزش و پرورش و پس از طی تشریفات و مراحل قانونی و با رعایت جنبه های غیرانتفاعی در هر مورد و ضوابط و مقررات مربوط
# 	 ...
# 	 نصب و راه اندازی و نگهداری انواع لوازم خانگی، گوشی های موبایل، لوازم صوتی و تصویری و قطعات یدکی مربوطه، کالاهای الکتریکی، الکترونیکی، ورزشی و تجهیزات پزشکی، کامپیوتر و قطعات کامپیوتر و تجهیزات شبکه های کامپیوتری، تجهیزات گرمایش و سرمایش
# 	 انجام کلیه امورپیمانکاری مربوط به ساخت راهها نظیرراههای اصلی وفرعی وبزرگراهها راههای ریلی باند فرودگاه سیستم های انتقال هوایی پایدار تونل ها پل ها راههای زیرزمینی
# 	 تصدی به فعالیت خدماتی و نظافتی، نمایشگاه ها و انبارهای عمومی و خدمات عمومی (نظیر نامه رسانی، تلفن چی، تنظیفات)
#
# Cluster 17, #28 Elements
# 	 آموزش آشپزی
# 	 انبوه سازی
# 	 تجارت الکترونیک
# 	 ...
# 	 سرمایه گذاری
# 	 سرمایه گذاری
# 	 انجام کلیه امور پیمانکاری از جمله طراحی، محاسبه، اجرا، نظارت، سرمایه گذاری و مشاوره پروژه های عمرانی اعم از آجری، سنگی، بتنی و فلزی
#
# Cluster 18, #28 Elements
# 	 انجام تحقیقات لازم و ارائه نظر مشورتی و حقوقی در خصوص تهیه لوایح و طرحهای مربوط به قوانین کار و تامین اجتماعی و مسائل رفاهی و حقوق قانونی کارفرمایان به مراجع ذیربط
# 	 احیا اراضی مسلوب المنفعه دولتی، خصوصی و منابع ملی اراضی همجوار پس از اخذ مجوز های قانونی براساس قوانین موجود
# 	 انجام فعالیت ها و ایجاد مجتمع های مرتبط با کشاورزی از قبیل گلخانه، دامپروری، پرورش طیور، زنبورداری، نوغانداری و آبزی پروری و خدمات مرتبط با این فعالیت ها
# 	 ...
# 	 نیروگاه های تجدیدپذیر متصل به شبکه برق سراسری ( نیروگاه های خورشیدی ، نیروگاه های بادی ، زباله سوز ، سامانه های پیل سوختی ، زیست توده ، آبی ، توربین های انبساطی ) در مقیاس های کیلوواتی و مگاواتی و خانگی و نیروگاهی
# 	 لوازم خودرویی وانواع جرثقیل شمال، جرثقیل های تلسکوپی و بوم خشک (به منظور شمع کوبی) و منضمات مربوط که عبارتند از انواع لودر، چکش کوبش بعلاوه سیستم های ویبراسیون با قطعات یدکی مرتبط و تجهیزات راهسازی و قطعات یدکی مربوطه
# 	 ارائه خدمات پیشخوان دولت الکترونیک از قبیل ایجاد و بهره برداری و انجام کلیه خدمات مرتبط و قابل ارائه در دفاتر پیشخوان دولت و بخش عمومی غیردولتی
#
# Cluster 19, #28 Elements
# 	 نظارت فنی در زمینه فعالیتها و خدمات رایانه‌ای طراحی وب میزبانی ،شبکه‌های رایانه‌ای
# 	 مدیریت زمان
# 	 سموم زیستی وشیمیایی
# 	 ...
# 	 زیرسازی
# 	 انتقال زباله
# 	 مدیریت زمان
#
# Cluster 20, #28 Elements
# 	 صنعتی
# 	 تنظیفات
# 	 حق العمل کاری
# 	 ...
# 	 تنظیفات
# 	 حق العمل کاری
# 	 انجام مطالعات
#
# Cluster 21, #27 Elements
# 	 خرید اصلاح کننده آب
# 	 خدمات شهری
# 	 درخت کاری
# 	 ...
# 	 خاکبرداری
# 	 ارائه خدمات مامایی
# 	 شرکت عمرانی
#
# Cluster 22, #27 Elements
# 	 کافی شاپ
# 	 پوشش (لاینیگ)
# 	 کانال کشی
# 	 ...
# 	 فروش
# 	 گیوه بافی
# 	 گیوه بافی
#
# Cluster 23, #26 Elements
# 	 و مدیریت طرح در زمینه موضوع شرکت
# 	 ایجاد شعب
# 	 پیگیری امور گمرگی
# 	 ...
# 	 گل کاری
# 	 چمن کاری
# 	 آبیاری
#
# Cluster 24, #26 Elements
# 	 صادرات اصلاح کننده آب
# 	 واردات اصلاح کننده آب
# 	 ساخت راه و باند، راه آهن، مترو، باند و فرودگاه، برج مراقبت
# 	 ...
# 	 ساختمان
# 	 ساختمان
# 	 نامه رسانی
#
# Cluster 25, #25 Elements
# 	 بازاریابی الکترونیکی
# 	 حمل‌و‌نقل درون شهری
# 	 خرید مواد شیمیایی
# 	 ...
# 	 نازک کاری
# 	 سازه های هیدورلیکی
# 	 شرکت نمایشگاه ها
#
# Cluster 26, #25 Elements
# 	 رستوران داری
# 	 ایجاد پیاده رو
# 	 فروش اصلاح کننده آب
# 	 ...
# 	 رختشوی خانه
# 	 نصب و فروش آپشن خودرو
# 	 مدیریت بحران
#
# Cluster 27, #25 Elements
# 	 کنتور خوانی
# 	 خط کشی خیابان
# 	 ارائه خدمات آنلاین وب و خدمات مبتنی بر فناوری ابری (lou)
# 	 ...
# 	 خرید
# 	 خاکریزی
# 	 خرید
