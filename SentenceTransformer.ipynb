# %%
"""
This is a simple application for sentence embeddings: semantic search

We have a corpus with various sentences. Then, for a given query sentence,
we want to find the most similar sentence in this corpus.

This script outputs for various queries the top 5 most similar sentences in the corpus.
"""
from sentence_transformers import SentenceTransformer, util
import torch

embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Corpus with example sentences
corpus = ['مشاوره، طراحی و اجرای سیستم های آتش نشانی و اعلام و اطفای حریق',
'ارائه خدمات و کالا در فضای مجازی',
'خرید و فروش اینترنتی انواع کالا و خدمات مجاز از طریق ایجاد و راه اندازی وب سایت و پرداخت آنلاین',
'مشاوره و طراحی سامانه تجاری اینترنتی و فروشگاه های مجازی جهت بازاریابی محصولات',
'مشاوره و طراحی و اجرا در زمینه فعالیت ها و طراحی وب و میزبانی',
'تولید و پشتیبانی نرم افزارهای مجاز غیررسانه ای',
'عملیات بارگیری و تخلیه و یا ترخیص کالا',
'صادرات و واردات کلیه کالاهای مجاز بازرگانی']

corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)

# Query sentences:
queries = ['A man is eating pasta.', 'Someone in a gorilla costume is playing a set of drums.', 'A cheetah chases prey on across a field.']


# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(5, len(corpus))
for query in queries:
    query_embedding = embedder.encode(query, convert_to_tensor=True)

    # We use cosine-similarity and torch.topk to find the highest 5 scores
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(corpus[idx], "(Score: {:.4f})".format(score))

    """
    # Alternatively, we can also use util.semantic_search to perform cosine similarty + topk
    hits = util.semantic_search(query_embedding, corpus_embeddings, top_k=5)
    hits = hits[0]      #Get the hits for the first query
    for hit in hits:
        print(corpus[hit['corpus_id']], "(Score: {:.4f})".format(hit['score']))
    """
# Out:
# ...
#
#
# Query: A man is eating pasta.
#
# Top 5 most similar sentences in corpus:
# مشاوره و طراحی و اجرا در زمینه فعالیت ها و طراحی وب و میزبانی (Score: -0.0096)
# ارائه خدمات و کالا در فضای مجازی (Score: -0.0274)
# عملیات بارگیری و تخلیه و یا ترخیص کالا (Score: -0.0304)
# صادرات و واردات کلیه کالاهای مجاز بازرگانی (Score: -0.0305)
# تولید و پشتیبانی نرم افزارهای مجاز غیررسانه ای (Score: -0.0435)
#
#
# ...
#
#
# Query: Someone in a gorilla costume is playing a set of drums.
#
# Top 5 most similar sentences in corpus:
# ارائه خدمات و کالا در فضای مجازی (Score: -0.0186)
# خرید و فروش اینترنتی انواع کالا و خدمات مجاز از طریق ایجاد و راه اندازی وب سایت و پرداخت آنلاین (Score: -0.0255)
# عملیات بارگیری و تخلیه و یا ترخیص کالا (Score: -0.0451)
# تولید و پشتیبانی نرم افزارهای مجاز غیررسانه ای (Score: -0.0534)
# مشاوره و طراحی و اجرا در زمینه فعالیت ها و طراحی وب و میزبانی (Score: -0.0555)
#
#
# ...
#
#
# Query: A cheetah chases prey on across a field.
#
# Top 5 most similar sentences in corpus:
# ...
